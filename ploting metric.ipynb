# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/home/gerald/Documents/AI_ML_Aug29/cementStrengthPrediction/code/cement_strength_reg'

# %%
ls
# Out:
# application_logging/                      prediction_Validation_Insertion.py
# app.yaml                                  preprocessing_data/
# AzureBlobStorage/                         Problem Statement.docx
# best_model_finder/                        __pycache__/
# data_ingestion/                           RandomForestRegressor0.xlsx
# data_preprocessing/                       RandomForestRegressor1.xlsx
# DataTransformation_Prediction/            randomForestRegressor3.xlsx
# DataTransform_Training/                   RandomForestRegressor3.xlsx
# DataTypeValidation_Insertion_Prediction/  requirements.txt
# DataTypeValidation_Insertion_Training/    Requirements.txt
# EDA/                                      schema_prediction.json
# file_operations/                          schema_training.json
# flask_monitoringdashboard.db              str(name).xlsx
# main.py                                   templates/
# manifest.yml                              TrainingArchiveBadData/
# ...

# %%
import pandas as pd
df1=pd.read_excel("xg-BoostRegressor0.xlsx",index_col=0)
df1
# Out:
#      LinearRegression                              randomForestRegressor  \
# 0            0.866315                                           0.866404
# 1  LinearRegression()  RandomForestRegressor(min_samples_split=4, n_e...
# 2           23.813329                                           23.79745
# 3            3.748347                                           3.396978
#
#                                    xg-BoostRegressor  \
# 0                                           0.877996
# 1  XGBRegressor(base_score=0.5, booster='gbtree',...
# 2                                          21.732553
# 3                                            3.35438
#
#                                decisionTreeRegressor  \
# 0                                           0.703911
# 1  DecisionTreeRegressor(max_depth=6, min_samples...
# 2                                          52.742297
# 3                                            5.59112
#
#                                   ada-BoostRegressor
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0                int64
# LinearRegression         object
# randomForestRegressor    object
# xg-BoostRegressor        object
# decisionTreeRegressor    object
# ada-BoostRegressor       object
# dtype: object

# %%
df1.dtypes
# Out:
# Unnamed: 0                int64
# LinearRegression         object
# randomForestRegressor    object
# xg-BoostRegressor        object
# decisionTreeRegressor    object
# ada-BoostRegressor       object
# dtype: object

# %%
X=pd.to_numeric(df1.iloc[0,:])
print(X)
# Out:
# LinearRegression         0.866315
# randomForestRegressor    0.866404
# xg-BoostRegressor        0.877996
# decisionTreeRegressor    0.703911
# ada-BoostRegressor       0.827310
# Name: 0, dtype: float64

# %%
X
# Out:
# LinearRegression         0.866315
# randomForestRegressor    0.866404
# xg-BoostRegressor        0.877996
# decisionTreeRegressor    0.703911
# ada-BoostRegressor       0.827310
# Name: 0, dtype: float64

# %%
X1=pd.to_numeric(df1.iloc[2,:])
print(X1)
# Out:
# LinearRegression         23.813329
# randomForestRegressor    23.797450
# xg-BoostRegressor        21.732553
# decisionTreeRegressor    52.742297
# ada-BoostRegressor       30.761271
# Name: 2, dtype: float64

# %%
X2=pd.to_numeric(df1.iloc[3,:])
print(X2)
# Out:
# LinearRegression         3.748347
# randomForestRegressor    3.396978
# xg-BoostRegressor        3.354380
# decisionTreeRegressor    5.591120
# ada-BoostRegressor       4.198526
# Name: 3, dtype: float64

# %%
df1.dtypes
# Out:
# Unnamed: 0                int64
# LinearRegression         object
# randomForestRegressor    object
# xg-BoostRegressor        object
# decisionTreeRegressor    object
# ada-BoostRegressor       object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X) # creating the graph between WCSS and the number of clusters
plt.title('r2 error vs Models')
#plt.xlabel()
#plt.ylabel('WCSS')
#plt.legend(lines,labels,loc='best', ncol=3,fontsize=14)

plt.plot(X.index,X,marker ='o',markersize=12, color = 'g') 
#plt.setp(X.get_xticklabels(),rotation=30, horizontalalignment='right')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4], <a list of 5 Text xticklabel objects>)

# %%
plt.plot(X1) # creating the graph between WCSS and the number of clusters
plt.title('MSE error plot')
#plt.xlabel()
#plt.ylabel('WCSS')
#plt.legend(lines,labels,loc='best', ncol=3,fontsize=14)

plt.plot(X1.index,X1,marker ='*',markersize=12, color = 'b') 
#plt.setp(X.get_xticklabels(),rotation=30, horizontalalignment='right')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4], <a list of 5 Text xticklabel objects>)

# %%
plt.plot(X2) # creating the graph between WCSS and the number of clusters
plt.title('MAE error plot')
#plt.xlabel()
#plt.ylabel('WCSS')
#plt.legend(lines,labels,loc='best', ncol=3,fontsize=14)
plt.plot(X2.index,X2,marker ='o',markersize=12, color = 'y') 
#plt.setp(X.get_xticklabels(),rotation=30, horizontalalignment='right')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4], <a list of 5 Text xticklabel objects>)

# %%
#% matplotlib inline
plt.rcParams["figure.figsize"] = [10, 12] 

plt.clf()
ax=[ax1,ax2,ax3]
fig, (ax1, ax2,ax3) = plt.subplots(3)
fig.suptitle('Regression Analysis Metric for cluster1')
ax1.plot(X,color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12)
ax2.plot(X1,color='blue', marker='s', linestyle='dashed',linewidth=2, markersize=12)
ax3.plot(X2,color='grey', marker='*', linestyle='dashed',linewidth=2, markersize=12)

ax1.set_title("r2 error vs Model",horizontalalignment='center')
ax2.set_title("Root Mean Square vs Model")
ax3.set_title("Root Absolute error vs Model")


ax1.set(ylabel='R2 error')
ax2.set(ylabel='MSE')
ax3.set(ylabel='ASE')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %%
list(X)
# Out:
# [0.8663146952998313,
#  0.8664038393659657,
#  0.877995932534223,
#  0.7039107792983308,
#  0.8273097423692742]

# %%
for i, v in enumerate(list(X)):
    print(i,v)
    print(str(v))
# Out:
# 0 0.8663146952998313
# 0.8663146952998313
# 1 0.8664038393659657
# 0.8664038393659657
# 2 0.877995932534223
# 0.877995932534223
# 3 0.7039107792983308
# 0.7039107792983308
# 4 0.8273097423692742
# 0.8273097423692742

# %%
def plotfunc(X,X1,X2):
    
   #% matplotlib inline
    plt.rcParams["figure.figsize"] = [10, 12] 

    plt.clf()
    

    fig, (ax1, ax2,ax3) = plt.subplots(3)
    fig.suptitle('Regression Analysis Metric for cluster1')
    ax1.plot(X,color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12)
    ax2.plot(X1,color='blue', marker='s', linestyle='dashed',linewidth=2, markersize=12)
    ax3.plot(X2,color='grey', marker='*', linestyle='dashed',linewidth=2, markersize=12)

    ax1.set_title("r2 error vs Model",horizontalalignment='center')
    ax2.set_title("Root Mean Square vs Model")
    ax3.set_title("Root Absolute error vs Model")


    ax1.set(ylabel='R2 error')
    ax2.set(ylabel='MSE')
    ax3.set(ylabel='ASE')
    
    #ax1.annotate(y,ha='center',fontsize = 14,color='k')
    #plt.text(X, str(X))
    #list1 =X,X1,X2
    #for values in list1:
    for i, v in enumerate(list(X)):

        label ="{:,.4f} ".format(v)

        ax1.annotate(label, xy=(i,v), xytext=(-10,10), textcoords='offset points')
        #ax2.annotate(label, xy=(i,v), xytext=(-10,10), textcoords='offset points')
        #ax3.annotate(label, xy=(i,v), xytext=(-10,10), textcoords='offset points')
 
    plt.subplots_adjust(left=0.1,
                        bottom=0.1, 
                        right=0.9, 
                        top=0.9, 
                        wspace=0.4, 
                        hspace=0.4)
    plt.savefig('cluster1_training metrics')
    plt.show(block=)

plotfunc(X,X1,X2)

# %%
pwd
# Out:
# '/home/gerald/Documents/AI_ML_Aug29/cementStrengthPrediction/code/cement_strength_reg'

# %%
ls
# Out:
# application_logging/                      prediction_Validation_Insertion.py
# app.yaml                                  preprocessing_data/
# AzureBlobStorage/                         Problem Statement.docx
# best_model_finder/                        __pycache__/
# cluster1_training metrics.png             RandomForestRegressor0.xlsx
# data_ingestion/                           RandomForestRegressor1.xlsx
# data_preprocessing/                       randomForestRegressor3.xlsx
# DataTransformation_Prediction/            RandomForestRegressor3.xlsx
# DataTransform_Training/                   requirements.txt
# DataTypeValidation_Insertion_Prediction/  Requirements.txt
# DataTypeValidation_Insertion_Training/    schema_prediction.json
# EDA/                                      schema_training.json
# file_operations/                          str(name).xlsx
# flask_monitoringdashboard.db              templates/
# main.py                                   TrainingArchiveBadData/
# ...

# %%
import os
path='/home/gerald/Documents/AI_ML_Aug29/cementStrengthPrediction/code/cement_strength_reg'
files=os.listdir(path)

# %%
import re
import os
path='/home/gerald/Documents/AI_ML_Aug29/cementStrengthPrediction/code/cement_strength_reg'
files=os.listdir(path)
#dir=o
for i in files:
    
    note=re.search("^xg-model[-][a-zA-Z]{2,17}[0-9]",i)
    print("the results are",note)
# Out:
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# the results are None
# ...

# %%
str(files)
# Out:
# "['flask_monitoringdashboard.db', '.gcloudignore', 'RandomForestRegressor3.xlsx', '.ipynb_checkpoints', 'schema_prediction.json', 'cluster1_training metrics.png', '.~lock.xg-BoostRegressor0.xlsx#', 'DataTypeValidation_Insertion_Prediction', 'RandomForestRegressor1.xlsx', 'predictFromModel.py', 'AzureBlobStorage', 'Training_Database', 'Prediction_Logs', 'mongoDBoperation.py', 'Prediction_FileFromDB', 'xg-BoostRegressor1.xlsx', 'manifest.yml', 'prediction_Validation_Insertion.py', 'best_model_finder', 'Materaial_strength_pred_5-algorithms', 'Prediction_Raw_Data_Validation', 'Training_Batch_Files', 'Prediction_Batch_files', 'DataTransform_Training', 'str(name).xlsx', 'templates', 'TrainingArchiveBadData', 'models', 'application_logging', 'RandomForestRegressor0.xlsx', 'Training_Raw_files_validated', 'xg-BoostRegressor0.xlsx', 'DataTransformation_Prediction', 'Prediction_Database', 'EDA', 'trainingModel.py', '.git', 'Training_FileFromDB', 'data_ingestion', 'ploting metric.ipynb', 'DataTy
# ...

# %%
note.start()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-103ca0d1850c> in <module>
# ----> 1 note.start()
#
# AttributeError: 'NoneType' object has no attribute 'start'
